# %%
#판다스 설치
# !pip install pandas

# %%
import pandas

# %%
#시리즈(Series)

menu = pandas. Series(["비빔밥", "김치찌개", "된장찌개"])
menu
# Out:
# 0     비빔밥
# 1    김치찌개
# 2    된장찌개
# dtype: object

# %%
type(menu)
# Out:
# pandas.core.series.Series

# %%
price = pandas.Series([1000,2000,3000])
price
# Out:
# 0    1000
# 1    2000
# 2    3000
# dtype: int64

# %%
# 데이터프레임(DataFrame)

import pandas as pd

df = pd.DataFrame( {
    "메뉴": menu,
    "가격": price
})

df
# Out:
#      메뉴    가격
# 0   비빔밥  1000
# 1  김치찌개  2000
# 2  된장찌개  3000

# %%
df = pd.DataFrame({
    "메뉴": ["비빔밥", "김치찌개", "된장찌개"],
    "가격": [10000, 9000, 8000],
    "원산지": ["한국", "한국", "한국"] 
})

df
# Out:
#      메뉴     가격 원산지
# 0   비빔밥  10000  한국
# 1  김치찌개   9000  한국
# 2  된장찌개   8000  한국

# %%
#컬럼 선택
df["메뉴"]
df["가격"]
# Out:
# 0    10000
# 1     9000
# 2     8000
# Name: 가격, dtype: int64

# %%
df[["메뉴","가격"]]
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
# 02. 데이터 저장 및 불러오기

data = {
    "메뉴": ["아메리카노", "카페라떼", "카페모카", " 카푸치노", "에스프레소", "밀크티", "녹차"],
    "가격": ["4500", "5000", "3000", " 7000", "500", "300", "1000"],
    "칼로리": ["450", "50", "30", " 70", "5", "3", "100"],
}

df = pd.DataFrame(data)
df
# Out:
#       메뉴     가격  칼로리
# 0  아메리카노   4500  450
# 1   카페라떼   5000   50
# 2   카페모카   3000   30
# 3   카푸치노   7000   70
# 4  에스프레소    500    5
# 5    밀크티    300    3
# 6     녹차   1000  100

# %%
# csv 파일로 저장
df.to_csv("temp.csv", index=False)

# %%
# csv 파일로 불러오기

pd.read_csv("temp.csv")
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500  450
# 1   카페라떼  5000   50
# 2   카페모카  3000   30
# 3   카푸치노  7000   70
# 4  에스프레소   500    5
# 5    밀크티   300    3
# 6     녹차  1000  100

# %%
#03. 탐색적 데이터 분석(EDA)

df = pd.read_csv("temp.csv")

df.head()  ## head: 상위 5개 행만 불러옴
df.head(2) ## 상위 n개만 불러옴

df.tail() ## tail : 하위 5개 행 불러옴
df.tail(3) ## tail : 하위 n개 행 불러옴
# Out:
#       메뉴    가격  칼로리
# 4  에스프레소   500    5
# 5    밀크티   300    3
# 6     녹차  1000  100

# %%
#데이터 프레임의 크기 (행,열)

df. shape
# Out:
# (7, 3)

# %%
# 컬럼별 자료형
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
# 상관관계
df.corr(numeric_only=True)
# Out:
#            가격       칼로리
# 가격   1.000000  0.330027
# 칼로리  0.330027  1.000000

# %%
# 고유한 값의 개수

data = {
    "car": ["Sedan", "SUV", "Sedan", "SUV", "SUV", "Sedan", "Sedan", "Sedan", "Sedan", "SUV"],
    "size": ["S","M", "M", "S", "L", "S", "L", "M","M", "L" ]
}

df_car = pd.DataFrame(data)
df_car.head(3)

df_car.nunique()
# Out:
# car     2
# size    3
# dtype: int64

# %%
df_car.value_counts()
print(df_car["car"].value_counts())
print(df_car["size"].value_counts())
# Out:
# car
# Sedan    6
# SUV      4
# Name: count, dtype: int64
# size
# M    4
# S    3
# L    3
# Name: count, dtype: int64

# %%
#기술통계

df_car.describe()
# Out:
#           car size
# count      10   10
# unique      2    3
# top     Sedan    M
# freq        6    4

# %%
df.describe()
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500  450
# 1   카페라떼  5000   50
# 2   카페모카  3000   30
# 3   카푸치노  7000   70
# 4  에스프레소   500    5
# 5    밀크티   300    3
# 6     녹차  1000  100

# %%
# 기술통계(object 자료형)

df.describe(include="object")
# Out:
#            메뉴
# count       7
# unique      7
# top     아메리카노
# freq        1

# %%
# 4. 자료형 변환

data = {
    "메뉴": ["아메리카노", "카페라떼", "카페모카", " 카푸치노", "에스프레소", "밀크티", "녹차"],
    "가격": [4500.0, 5000.0, 3000.0, 7000.0, 500.0, 300.0, 1000.0],
    "칼로리": [450.0, 50.0, 30.0, 70.0, 5.0, 3.0, 100.0],
}
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      float64
#  2   칼로리     7 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df["가격"] = df["가격"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 300.0+ bytes

# %%
df["가격"] = df["가격"].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      float64
#  2   칼로리     7 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 300.0+ bytes

# %%
#5. 새로운 컬럼 추가

df = pd. read_csv("temp.csv")
df.head(2)
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500  450
# 1   카페라떼  5000   50

# %%
df["new"] = 0
df
# Out:
#       메뉴    가격  칼로리  new
# 0  아메리카노  4500  450    0
# 1   카페라떼  5000   50    0
# 2   카페모카  3000   30    0
# 3   카푸치노  7000   70    0
# 4  에스프레소   500    5    0
# 5    밀크티   300    3    0
# 6     녹차  1000  100    0

# %%
#기존 컬럼을 사용한 계산
discount = 0.2
df["할인가"] = df["가격"] * (1-discount)
df
# Out:
#       메뉴    가격  칼로리  new     할인가
# 0  아메리카노  4500  450    0  3600.0
# 1   카페라떼  5000   50    0  4000.0
# 2   카페모카  3000   30    0  2400.0
# 3   카푸치노  7000   70    0  5600.0
# 4  에스프레소   500    5    0   400.0
# 5    밀크티   300    3    0   240.0
# 6     녹차  1000  100    0   800.0

# %%
# 6. 데이터 삭제

df = pd.read_csv("temp.csv")
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500  450
# 1   카페라떼  5000   50
# 2   카페모카  3000   30
# 3   카푸치노  7000   70
# 4  에스프레소   500    5
# 5    밀크티   300    3
# 6     녹차  1000  100

# %%
# 행 삭제
df = df.drop(1, axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 2
#       1 # 행 삭제
# ----> 2 df = df.drop(1, axis=0)
#
# File c:\Users\krcea\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
# ...

# %%
df = df.drop(5,axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df = df.drop(5,axis=0, inplace=True)
#
# File c:\Users\krcea\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
# ...

# %%
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500  450
# 2   카페모카  3000   30
# 3   카푸치노  7000   70
# 4  에스프레소   500    5
# 6     녹차  1000  100

# %%
#컬럼(열) 삭제

df = df.drop("칼로리", axis = 1)

# %%
df
# Out:
#       메뉴    가격
# 0  아메리카노  4500
# 2   카페모카  3000
# 3   카푸치노  7000
# 4  에스프레소   500
# 6     녹차  1000
