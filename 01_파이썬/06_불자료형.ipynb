# %%
#불(bool) 자료형

a = True
b = False

type(a)
type(b)
# Out:
# bool

# %%
1 == 1 ## '==' 같다

print(2 > 1)
print(1 > 2)
print(2 >= 1)
print(2 <= 1)
print(1 != 2) ## 같지 않다
# Out:
# True
# False
# True
# False
# True

# %%
print(bool(1))
print(bool(0))
print(bool(""))
print(bool("python"))
print(bool([]))
print(bool([1,2]))
# Out:
# True
# False
# False
# True
# False
# True

# %%
# and 연산자
print(True and True)
print(False and True)
print(False and Fales)
# Out:
# True
# False
# False

# %%
# or 연산자
print(True or True)
print(False or True)
print(False or False)


# 변수 a 
a = 17

print(a >= 10 and a < 20)
# Out:
# True
# True
# False
# True
