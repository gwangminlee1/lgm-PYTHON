# %%
1+1
# Out:
# 2

# %%
print("hello world", "python")
# Out:
# hello world python

# %%
print("")

# %%
print(100+200)
print(100/(2+8))
# Out:
# 300
# 10.0

# %%
print("안녕"+"하세여")
# Out:
# 안녕하세여

# %%
type(100)
# Out:
# int

# %%
type(100.0)
# Out:
# float

# %%
print(True+True)
# Out:
# 2

# %%
americano = 4500
americano = americano + 1000
latte = 5000

print(americano)
print("americano")
print(latte)
print("latte")
print(americano+latte)
# Out:
# 5500
# americano
# 5000
# latte
# 10500

# %%
score = 89

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
else:
    print("C")
# Out:
# B

# %%
print("커피한잔하소")
# Out:
# 커피한잔하소

# %%
listbox = ["커피", "녹차", "블루베리", "오렌지주스"]

print(listbox[0])
print(listbox[1])
print(listbox[2])
print(listbox[3])
listbox.append("커피")
# Out:
# 커피
# 녹차
# 블루베리
# 오렌지주스
