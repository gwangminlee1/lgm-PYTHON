# %%
odd = [ 1,3,4,7,9]

a=[]
b=["life", "is", "too", "short"]
c=[1,2,"life","is"]
d=[1,2,["life","is"]]

# %%
a=[1,2,3,["a","b","c"]]
a[0]
a[3]
a[3]
# Out:
# ['a', 'b', 'c']

# %%
a=[1,2,["a","b",["life","is"]]]

a[2][2][1]
a[-1][-1][-1]
# Out:
# 'is'

# %%
a= [1,2,3,4,5]
a[0:2]
a[2:4]
a[0:4]
a[:4]
a[1:5]
a[:]
# Out:
# [1, 2, 3, 4, 5]

# %%
#리스트더하기
a=[1,2,3]
b=[4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a+b
#리스트 반복하기
a=[1,2,3]
a*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
#리스트 길이구하기
a=[1,2,3,4,5]
len(a)
# Out:
# 5

# %%
#리스트 요소 추가
a=[1,2,3]
a.append(4)
a.append([5,6])

# %%
#리스트 값을 수정하기
a=[1,2,3]
a[2]=4
#a[3]=5 / 리스트 범위를 벗어남

a.append(5)
a
# Out:
# [1, 2, 4, 5]

# %%
a=sorted(a, reverse=True)
a
# Out:
# [5, 4, 2, 1]

# %%
a.sort()
a
# Out:
# [1, 2, 4, 5]

# %%
a.reverse()
a
# Out:
# [5, 4, 3, 3, 3, 2, 1]

# %%
a.index(4)
a.index(1)
# Out:
# 6

# %%
a.insert(2,3)
a
# Out:
# [1, 2, 3, 3, 3, 4, 5]

# %%
#리스트 제거하기
a.remove(1)
a
# Out:
# [5, 4, 3, 3, 3, 2]

# %%
#리스트 요소 끄집어내기
a = [5,4,3,2,1]
result = a.pop(2)
print(result)
# Out:
# 3

# %%
#리스트 확장 - extend
a=[1,2,3]
a.extend([4,5])
a
#a+[4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
ff
