# %%
money = 10000

if money : 
    print("택시를 타고 가라")
else : 
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
money = 2000
card = True

if money >= 3000 or card : 
    print("택시를 타고 가라")
else : 
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
## in, not in
# x in 리스트
# x in 튜플
# x in 문자열

print(1 in [1, 2, 3])
print("f" in ("a", "b", "c"))
print("j" in "python")

print(1 not in [1, 2, 3])
# Out:
# True
# False
# False
# False

# %%
pocket = ["paper", "cellphone", "money"]

if "money" in pocket :
    print("택시를 타고 가라")
else :
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
pocket = ["paper", "cellphone", "money"]

if "coin" in pocket :
    pass
else : 
    print("카드를 꺼내라")
# Out:
# 카드를 꺼내라

# %%
#다양한 조건을 판단하는 elif

pocket = ["paper", "cellphone"]
care = False

if "money" in pocket : 
    print("택시를 타고 가라")
else :
    if card:
         print("택시를 타고 가라")
    else:
         print("걸어 가라")
# Out:
# 택시를 타고 가라

# %%
pocket = ["paper", "cellphone"]
card = False

if "money" in pocket:
    print("택시를 타고 가라")
elif card:
    print("택시를 타고 가라")
else: 
    print("걸어 가라")
# Out:
# 걸어 가라

# %%
score = 78

if score >= 90:
    print("A")
elif score >= 80: ## 90 미만을 전제로 함
    print("B")    
elif score >= 70:
    print("C")
else:
    print("F")
# Out:
# C

# %%
#변수 = 참일 때 값 if 조건 else 거짓일 때 값

age = 27
status = "성인" if age >= 18 else "미성년"
print(status)

if age >=18:
    print("성인")
else:
    print("미성년")
# Out:
# 성인
# 성인
